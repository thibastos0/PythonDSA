# %%
import time
import win32com.client

# Inicia o Excel
File = win32com.client.gencache.EnsureDispatch("Excel.Application")

# torna ele visível/invisível
File.Visible = 1 # se 0 ele faz o processo em segundo plano sem mostrar o código

def atualiza_Ocorrencias_Monitoradas(caminho):
    
    # abre o arquivo
    Workbook = File.Workbooks.Open(caminho)
        
    # realiza a atualização dos dados.
    Workbook.RefreshAll()

    # utilizamenos o time.sleep() para que a aplicação aguarde até que a atualização ocorra por completo.
    time.sleep(30)

    # Salva a planilha
    Workbook.Save()
    
    Workbook.Close()
    
    return

caminho_PortaSO_DNB = (
'https://navbrasilgovbr.sharepoint.com/teams/PortalSO/Alta Floresta/SMS/03 Garantia da segurança/Ocorrências monitoradas/2023/MONITORAMENTO OCORRÊNCIAS_2023.xlsx',
'https://navbrasilgovbr.sharepoint.com/teams/PortalSO/Cruzeiro do Sul/SMS/03 Garantia da segurança/Ocorrências monitoradas/2023/MONITORAMENTO OCORRÊNCIAS_2023.xlsx',
'https://navbrasilgovbr.sharepoint.com/teams/PortalSO/Itaituba/SMS/03 Garantia da segurança/Ocorrências monitoradas/2023/MONITORAMENTO OCORRÊNCIAS_2023.xlsx',
'https://navbrasilgovbr.sharepoint.com/teams/PortalSO/Santarm/SMS/03 Garantia da segurança/Ocorrências monitoradas/2023/MONITORAMENTO OCORRÊNCIAS_2023.xlsx',
'https://navbrasilgovbr.sharepoint.com/teams/PortalSO/Tef/SMS/03 Garantia da segurança/Ocorrências monitoradas/2023/MONITORAMENTO OCORRÊNCIAS_2023.xlsx',
'https://navbrasilgovbr.sharepoint.com/teams/PortalSO/Carajs/SMS/03 Garantia da segurança/Ocorrências monitoradas/2023/MONITORAMENTO OCORRÊNCIAS_2023.xlsx',
'https://navbrasilgovbr.sharepoint.com/teams/PortalSO/Altamira/SMS/03 Garantia da segurança/Ocorrências monitoradas/2023/MONITORAMENTO OCORRÊNCIAS_2023.xlsx',
'https://navbrasilgovbr.sharepoint.com/teams/PortalSO/Imperatriz/SMS/03 Garantia da segurança/Ocorrências monitoradas/2023/MONITORAMENTO OCORRÊNCIAS_2023.xlsx',
'https://navbrasilgovbr.sharepoint.com/teams/PortalSO/Marab/SMS/03 Garantia da segurança/Ocorrências monitoradas/2023/MONITORAMENTO OCORRÊNCIAS_2023.xlsx',
'https://navbrasilgovbr.sharepoint.com/teams/PortalSO/Macap/SMS/03 Garantia da segurança/Ocorrências monitoradas/2023/MONITORAMENTO OCORRÊNCIAS_2023.xlsx',
'https://navbrasilgovbr.sharepoint.com/teams/PortalSO/Ilhus/SMS/03 Garantia da segurança/Ocorrências monitoradas/2023/MONITORAMENTO OCORRÊNCIAS_2023.xlsx',
'https://navbrasilgovbr.sharepoint.com/teams/PortalSO/Joo Pessoa/SMS/03 Garantia da segurança/Ocorrências monitoradas/2023/MONITORAMENTO OCORRÊNCIAS_2023.xlsx',
'https://navbrasilgovbr.sharepoint.com/teams/PortalSO/Juazeiro do norte/SMS/03 Garantia da segurança/Ocorrências monitoradas/2023/MONITORAMENTO OCORRÊNCIAS_2023.xlsx',
'https://navbrasilgovbr.sharepoint.com/teams/PortalSO/Campina Grande/SMS/03 Garantia da segurança/Ocorrências monitoradas/2023/MONITORAMENTO OCORRÊNCIAS_2023.xlsx',
'https://navbrasilgovbr.sharepoint.com/teams/PortalSO/Mossor/SMS/03 Garantia da segurança/Ocorrências monitoradas/2023/MONITORAMENTO OCORRÊNCIAS_2023.xlsx',
'https://navbrasilgovbr.sharepoint.com/teams/PortalSO/Parnaba/SMS/03 Garantia da segurança/Ocorrências monitoradas/2023/MONITORAMENTO OCORRÊNCIAS_2023.xlsx',
'https://navbrasilgovbr.sharepoint.com/teams/PortalSO/Petrolina/SMS/03 Garantia da segurança/Ocorrências monitoradas/2023/MONITORAMENTO OCORRÊNCIAS_2023.xlsx',
'https://navbrasilgovbr.sharepoint.com/teams/PortalSO/Teresina/SMS/03 Garantia da segurança/Ocorrências monitoradas/2023/MONITORAMENTO OCORRÊNCIAS_2023.xlsx',
'https://navbrasilgovbr.sharepoint.com/teams/PortalSO/Paulo Afonso/SMS/03 Garantia da segurança/Ocorrências monitoradas/2023/MONITORAMENTO OCORRÊNCIAS_2023.xlsx',
'https://navbrasilgovbr.sharepoint.com/teams/PortalSO/Vitria/SMS/03 Garantia da segurança/Ocorrências monitoradas/2023/MONITORAMENTO OCORRÊNCIAS_2023.xlsx',
'https://navbrasilgovbr.sharepoint.com/teams/PortalSO/Bauru/SMS/03 Garantia da segurança/Ocorrências monitoradas/2023/MONITORAMENTO OCORRÊNCIAS DNB-BU_2023.xlsx',
'https://navbrasilgovbr.sharepoint.com/teams/PortalSO/Bauru/SMS/03 Garantia da segurança/Ocorrências monitoradas/2023/MONITORAMENTO OCORRÊNCIAS ENB-AE_2023.xlsx',
'https://navbrasilgovbr.sharepoint.com/teams/PortalSO/Belo Horizonte/SMS/03 Garantia da segurança/Ocorrências monitoradas/2023/MONITORAMENTO OCORRÊNCIAS_2023.xlsx',
'https://navbrasilgovbr.sharepoint.com/teams/PortalSO/Barra do Garas/SMS/03 Garantia da segurança/Ocorrências monitoradas/2023/MONITORAMENTO OCORRÊNCIAS 2023.xlsx',
'https://navbrasilgovbr.sharepoint.com/teams/PortalSO/Goinia/SMS/03 Garantia da segurança/Ocorrências monitoradas/2023/MONITORAMENTO OCORRÊNCIAS_2023.xlsx',
'https://navbrasilgovbr.sharepoint.com/teams/PortalSO/Montes Claros/SMS/03 Garantia da segurança/Ocorrências monitoradas/2023/MONITORAMENTO OCORRÊNCIAS 2023.xlsx',
'https://navbrasilgovbr.sharepoint.com/teams/PortalSO/Palmas/SMS/03 Garantia da segurança/Ocorrências monitoradas/2023/MONITORAMENTO OCORRÊNCIAS 2023.xlsx',
'https://navbrasilgovbr.sharepoint.com/teams/PortalSO/Ribeiro Preto/SMS/03 Garantia da segurança/Ocorrências monitoradas/2023/MONITORAMENTO OCORRÊNCIAS_2023.xlsx',
'https://navbrasilgovbr.sharepoint.com/teams/PortalSO/Uberlndia/SMS/03 Garantia da segurança/Ocorrências monitoradas/2023/MONITORAMENTO OCORRÊNCIAS 2023.xlsx',
'https://navbrasilgovbr.sharepoint.com/teams/PortalSO/Uberaba/SMS/03 Garantia da segurança/Ocorrências monitoradas/2023/MONITORAMENTO OCORRÊNCIAS_2023.xlsx',
'https://navbrasilgovbr.sharepoint.com/teams/PortalSO/Galeo/SMS/03 Garantia da segurança/Ocorrências monitoradas/2023/MONITORAMENTO OCORRÊNCIAS_2023.xlsx',
'https://navbrasilgovbr.sharepoint.com/teams/PortalSO/Guarulhos/SMS/03 Garantia da segurança/Ocorrências monitoradas/2023/MONITORAMENTO OCORRÊNCIAS_2023.xlsx',
'https://navbrasilgovbr.sharepoint.com/teams/PortalSO/Jacarepagu/SMS/03 Garantia da segurança/Ocorrências monitoradas/2023/MONITORAMENTO OCORRÊNCIAS_2023.xlsx',
'https://navbrasilgovbr.sharepoint.com/teams/PortalSO/Campinas/SMS/03 Garantia da segurança/Ocorrências monitoradas/2023/MONITORAMENTO OCORRÊNCIAS_2023.xlsx',
'https://navbrasilgovbr.sharepoint.com/teams/PortalSO/Santos Dumont/SMS/03 Garantia da segurança/Ocorrências monitoradas/2023/MONITORAMENTO OCORRÊNCIAS_2023.xlsx',
'https://navbrasilgovbr.sharepoint.com/teams/PortalSO/Bag/SMS/03 Garantia da segurança/Ocorrências monitoradas/2023/MONITORAMENTO OCORRÊNCIAS_2023.xlsx',
'https://navbrasilgovbr.sharepoint.com/teams/PortalSO/Campos dos Goitacazes/SMS/03 Garantia da segurança/Ocorrências monitoradas/2023/MONITORAMENTO OCORRÊNCIAS_2023.xlsx',
'https://navbrasilgovbr.sharepoint.com/teams/PortalSO/Presidente Prudente/SMS/03 Garantia da segurança/Ocorrências monitoradas/2023/MONITORAMENTO OCORRÊNCIAS_2023.xlsx',
'https://navbrasilgovbr.sharepoint.com/teams/PortalSO/Joinville/SMS/03 Garantia da segurança/Ocorrências monitoradas/2023/MONITORAMENTO OCORRÊNCIAS_2023.xlsx',
'https://navbrasilgovbr.sharepoint.com/teams/PortalSO/Londrina/SMS/03 Garantia da segurança/Ocorrências monitoradas/2023/MONITORAMENTO OCORRÊNCIAS_2023.xlsx',
'https://navbrasilgovbr.sharepoint.com/teams/PortalSO/Maca/SMS/03 Garantia da segurança/Ocorrências monitoradas/2023/MONITORAMENTO OCORRÊNCIAS_2023.xlsx',
'https://navbrasilgovbr.sharepoint.com/teams/PortalSO/Navegantes/SMS/03 Garantia da segurança/Ocorrências monitoradas/2023/MONITORAMENTO OCORRÊNCIAS_2023.xlsx',
'https://navbrasilgovbr.sharepoint.com/teams/PortalSO/Pelotas/SMS/03 Garantia da segurança/Ocorrências monitoradas/2023/MONITORAMENTO OCORRÊNCIAS_2023.xlsx',
'https://navbrasilgovbr.sharepoint.com/teams/PortalSO/Ponta Por/SMS/03 Garantia da segurança/Ocorrências monitoradas/2023/MONITORAMENTO OCORRÊNCIAS_2023.xlsx'
)

for i in caminho_PortaSO_DNB:
    print("Em atualização: ", i[53:i.find("/SMS")])  
    atualiza_Ocorrencias_Monitoradas(i)
    
caminho_CompiladoPC = (r"C:\Users\Public\Documents\00 DSSO\3 GARANTIA\Ocorrências\Ocorrências Monitoradas - Análise.xlsx")
print("Em atualização: arquivo compilado.")

atualiza_Ocorrencias_Monitoradas(caminho_CompiladoPC)

    
# Fecha o Excel
File.Quit()
# Out:
# Em atualização:  Alta Floresta
# Em atualização:  Cruzeiro do Sul
# Em atualização:  Itaituba
# Em atualização:  Santarm
# Em atualização:  Tef
# Em atualização:  Carajs
# Em atualização:  Altamira
# Em atualização:  Imperatriz
# Em atualização:  Marab
# Em atualização:  Macap
# Em atualização:  Ilhus
# Em atualização:  Joo Pessoa
# Em atualização:  Juazeiro do norte
# Em atualização:  Campina Grande
# Em atualização:  Mossor
# Em atualização:  Parnaba
# Em atualização:  Petrolina
# Em atualização:  Teresina
# Em atualização:  Paulo Afonso
# Em atualização:  Vitria
# Em atualização:  Bauru
# Em atualização:  Bauru
# Em atualização:  Belo Horizonte
# Em atualização:  Barra do Garas
# Em atualização:  Goinia
# Em atualização:  Montes Claros
# Em atualização:  Palmas
# Em atualização:  Ribeiro Preto
# Em atualização:  Uberlndia
# Em atualização:  Uberaba
# Em atualização:  Galeo
# Em atualização:  Guarulhos
# Em atualização:  Jacarepagu
# Em atualização:  Campinas
# ...
